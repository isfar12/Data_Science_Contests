# %%
import cv2
import os
import numpy as np

# %%
DATASET_DIR="../imc_25/image-matching-challenge-2025/train/imc2024_lizard_pond"
THRESHOLD = 15

image_names = sorted(os.listdir(DATASET_DIR))
ref_name = image_names[0]   # choose one reference image

# %%
ref_path = os.path.join(DATASET_DIR, ref_name)
ref_img = cv2.imread(ref_path, cv2.IMREAD_GRAYSCALE)

sift = cv2.SIFT_create()
kp_ref, des_ref = sift.detectAndCompute(ref_img, None)

print("Reference image:", ref_name)
print("Keypoints:", len(kp_ref))
# Out:
# Reference image: lizard_00003.png
# Keypoints: 6895

# %%
bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)

edges = []

for other_name in image_names[1:]:
    other_path = os.path.join(DATASET_DIR, other_name)
    other_img = cv2.imread(other_path, cv2.IMREAD_GRAYSCALE)

    kp_o, des_o = sift.detectAndCompute(other_img, None)

    if des_o is None:
        continue

    matches = bf.match(des_ref, des_o)

    if len(matches) < 8:
        continue

    pts1 = np.float32([kp_ref[m.queryIdx].pt for m in matches])
    pts2 = np.float32([kp_o[m.trainIdx].pt for m in matches])

    F, mask = cv2.findFundamentalMat(
        pts1, pts2,
        cv2.FM_RANSAC,
        ransacReprojThreshold=1.0,
        confidence=0.99
    )

    inliers = 0 if mask is None else int(mask.sum())

    if inliers >= THRESHOLD:
        edges.append((ref_name, other_name, inliers))

    print(f"{ref_name} ↔ {other_name}: inliers = {inliers}")


sift = cv2.SIFT_create()
kp_ref, des_ref = sift.detectAndCompute(ref_img, None)

print("Reference image:", ref_name)
print("Keypoints:", len(kp_ref))
# Out:
# lizard_00003.png ↔ lizard_00013.png: inliers = 17
# lizard_00003.png ↔ lizard_00014.png: inliers = 16
# lizard_00003.png ↔ lizard_00017.png: inliers = 16
# lizard_00003.png ↔ lizard_00019.png: inliers = 15
# lizard_00003.png ↔ lizard_00034.png: inliers = 18
# lizard_00003.png ↔ lizard_00051.png: inliers = 19
# lizard_00003.png ↔ lizard_00055.png: inliers = 10
# lizard_00003.png ↔ lizard_00066.png: inliers = 11
# lizard_00003.png ↔ lizard_00070.png: inliers = 13
# lizard_00003.png ↔ lizard_00074.png: inliers = 13
# lizard_00003.png ↔ lizard_00075.png: inliers = 12
# lizard_00003.png ↔ lizard_00086.png: inliers = 12
# lizard_00003.png ↔ lizard_00087.png: inliers = 10
# lizard_00003.png ↔ lizard_00089.png: inliers = 11
# lizard_00003.png ↔ lizard_00107.png: inliers = 22
# lizard_00003.png ↔ lizard_00113.png: inliers = 18
# lizard_00003.png ↔ lizard_00140.png: inliers = 16
# lizard_00003.png ↔ lizard_00154.png: inliers = 16
# lizard_00003.png ↔ lizard_00160.png: inliers = 17
# lizard_00003.png ↔ lizard_00161.png: inliers = 18
# lizard_00003.png ↔ lizard_00164.png: inliers = 19
# lizard_00003.png ↔ lizard_00165.png: inliers = 22
# lizard_00003.png ↔ lizard_00169.png: inliers = 18
# lizard_00003.png ↔ lizard_00173.png: inliers = 18
# lizard_00003.png ↔ lizard_00175.png: inliers = 17
# lizard_00003.png ↔ lizard_00181.png: inliers = 19
# lizard_00003.png ↔ lizard_00190.png: inliers = 17
# lizard_00003.png ↔ lizard_00192.png: inliers = 17
# lizard_00003.png ↔ lizard_00195.png: inliers = 16
# lizard_00003.png ↔ lizard_00203.png: inliers = 16
# lizard_00003.png ↔ lizard_00212.png: inliers = 19
# lizard_00003.png ↔ lizard_00217.png: inliers = 19
# lizard_00003.png ↔ lizard_00226.png: inliers = 18
# lizard_00003.png ↔ lizard_00233.png: inliers = 17
# lizard_00003.png ↔ lizard_00236.png: inliers = 19
# lizard_00003.png ↔ lizard_00242.png: inliers = 22
# lizard_00003.png ↔ lizard_00244.png: inliers = 19
# lizard_00003.png ↔ lizard_00268.png: inliers = 18
# lizard_00003.png ↔ lizard_00278.png: inliers = 19
# lizard_00003.png ↔ lizard_00292.png: inliers = 19
# lizard_00003.png ↔ lizard_00307.png: inliers = 14
# lizard_00003.png ↔ lizard_00308.png: inliers = 14
# lizard_00003.png ↔ lizard_00318.png: inliers = 15
# lizard_00003.png ↔ lizard_00329.png: inliers = 13
# lizard_00003.png ↔ lizard_00350.png: inliers = 12
# lizard_00003.png ↔ lizard_00351.png: inliers = 13
# lizard_00003.png ↔ lizard_00361.png: inliers = 11
# lizard_00003.png ↔ lizard_00391.png: inliers = 18
# lizard_00003.png ↔ lizard_00402.png: inliers = 18
# lizard_00003.png ↔ lizard_00404.png: inliers = 18
# lizard_00003.png ↔ lizard_00415.png: inliers = 21
# lizard_00003.png ↔ lizard_00431.png: inliers = 27
# lizard_00003.png ↔ lizard_00435.png: inliers = 20
# lizard_00003.png ↔ lizard_00459.png: inliers = 157
# lizard_00003.png ↔ lizard_00466.png: inliers = 586
# lizard_00003.png ↔ lizard_00482.png: inliers = 12
# lizard_00003.png ↔ lizard_00492.png: inliers = 11
# lizard_00003.png ↔ lizard_00507.png: inliers = 17
# lizard_00003.png ↔ lizard_00512.png: inliers = 17
# lizard_00003.png ↔ lizard_00516.png: inliers = 16
# lizard_00003.png ↔ lizard_00519.png: inliers = 78
# lizard_00003.png ↔ lizard_00527.png: inliers = 19
# lizard_00003.png ↔ lizard_00531.png: inliers = 21
# lizard_00003.png ↔ lizard_00538.png: inliers = 44
# lizard_00003.png ↔ lizard_00544.png: inliers = 25
# lizard_00003.png ↔ lizard_00549.png: inliers = 13
# lizard_00003.png ↔ lizard_00551.png: inliers = 12
# lizard_00003.png ↔ lizard_00567.png: inliers = 9
# lizard_00003.png ↔ lizard_00568.png: inliers = 10
# lizard_00003.png ↔ lizard_00571.png: inliers = 7
# lizard_00003.png ↔ lizard_00580.png: inliers = 14
# lizard_00003.png ↔ lizard_00585.png: inliers = 11
# lizard_00003.png ↔ lizard_00591.png: inliers = 9
# lizard_00003.png ↔ lizard_00592.png: inliers = 10
# lizard_00003.png ↔ lizard_00606.png: inliers = 11
# lizard_00003.png ↔ lizard_00613.png: inliers = 10
# lizard_00003.png ↔ lizard_00616.png: inliers = 12
# lizard_00003.png ↔ lizard_00618.png: inliers = 9
# lizard_00003.png ↔ lizard_00633.png: inliers = 8
# lizard_00003.png ↔ lizard_00637.png: inliers = 10
# lizard_00003.png ↔ lizard_00668.png: inliers = 20
# lizard_00003.png ↔ lizard_00670.png: inliers = 19
# lizard_00003.png ↔ lizard_00674.png: inliers = 19
# lizard_00003.png ↔ lizard_00676.png: inliers = 16
# lizard_00003.png ↔ lizard_00682.png: inliers = 19
# lizard_00003.png ↔ lizard_00698.png: inliers = 17
# lizard_00003.png ↔ lizard_00707.png: inliers = 21
# lizard_00003.png ↔ lizard_00716.png: inliers = 16
# lizard_00003.png ↔ lizard_00720.png: inliers = 18
# lizard_00003.png ↔ outliers_img_20230617_181536.png: inliers = 20
# lizard_00003.png ↔ outliers_img_20230617_181545.png: inliers = 18
# lizard_00003.png ↔ outliers_img_20230617_181719.png: inliers = 21
# lizard_00003.png ↔ outliers_img_20230617_181721.png: inliers = 19
# lizard_00003.png ↔ outliers_img_20230617_181724.png: inliers = 17
# lizard_00003.png ↔ outliers_img_20230617_181726.png: inliers = 20
# lizard_00003.png ↔ outliers_img_20230617_181728.png: inliers = 18
# lizard_00003.png ↔ outliers_img_20230617_181729.png: inliers = 21
# lizard_00003.png ↔ outliers_img_20230617_181747.png: inliers = 21
# lizard_00003.png ↔ outliers_img_20230617_181748.png: inliers = 18
# lizard_00003.png ↔ outliers_img_20230617_181749.png: inliers = 19
# lizard_00003.png ↔ outliers_img_20230617_181752.png: inliers = 17
# lizard_00003.png ↔ outliers_img_20230617_181850.png: inliers = 19
# lizard_00003.png ↔ outliers_img_20230617_181852.png: inliers = 17
# lizard_00003.png ↔ outliers_img_20230617_181853.png: inliers = 17
# lizard_00003.png ↔ outliers_img_20230617_181854.png: inliers = 20
# lizard_00003.png ↔ outliers_img_20230617_181855.png: inliers = 17
# lizard_00003.png ↔ outliers_img_20230617_181856.png: inliers = 20
# lizard_00003.png ↔ outliers_img_20230617_181858.png: inliers = 19
# lizard_00003.png ↔ outliers_img_20230617_181901.png: inliers = 18
# lizard_00003.png ↔ outliers_img_20230617_181905.png: inliers = 21
# lizard_00003.png ↔ outliers_img_20230617_181910.png: inliers = 19
# lizard_00003.png ↔ outliers_img_20230617_181912.png: inliers = 19
# lizard_00003.png ↔ outliers_img_20230617_181914.png: inliers = 19
# lizard_00003.png ↔ outliers_img_20230617_182716.png: inliers = 18
# lizard_00003.png ↔ outliers_img_20230617_182718.png: inliers = 21
# lizard_00003.png ↔ outliers_img_20230617_195104.png: inliers = 19
# lizard_00003.png ↔ outliers_img_20230617_202436.png: inliers = 22
# lizard_00003.png ↔ outliers_img_20230617_202438.png: inliers = 18
# lizard_00003.png ↔ outliers_img_20230617_211228.png: inliers = 16
# lizard_00003.png ↔ outliers_img_20230617_211229.png: inliers = 17
# lizard_00003.png ↔ outliers_img_20230617_212007.png: inliers = 17
# lizard_00003.png ↔ outliers_img_20230617_212014.png: inliers = 17
# lizard_00003.png ↔ outliers_img_20230617_212059.png: inliers = 16
# lizard_00003.png ↔ pond_00006.png: inliers = 17
# lizard_00003.png ↔ pond_00007.png: inliers = 19
# lizard_00003.png ↔ pond_00011.png: inliers = 16
# lizard_00003.png ↔ pond_00016.png: inliers = 21
# lizard_00003.png ↔ pond_00022.png: inliers = 17
# lizard_00003.png ↔ pond_00030.png: inliers = 17
# lizard_00003.png ↔ pond_00043.png: inliers = 20
# lizard_00003.png ↔ pond_00047.png: inliers = 18
# lizard_00003.png ↔ pond_00070.png: inliers = 19
# lizard_00003.png ↔ pond_00086.png: inliers = 18
# lizard_00003.png ↔ pond_00095.png: inliers = 19
# lizard_00003.png ↔ pond_00101.png: inliers = 19
# lizard_00003.png ↔ pond_00122.png: inliers = 19
# lizard_00003.png ↔ pond_00129.png: inliers = 18
# lizard_00003.png ↔ pond_00135.png: inliers = 19
# lizard_00003.png ↔ pond_00143.png: inliers = 18
# lizard_00003.png ↔ pond_00162.png: inliers = 19
# lizard_00003.png ↔ pond_00181.png: inliers = 18
# lizard_00003.png ↔ pond_00195.png: inliers = 19
# lizard_00003.png ↔ pond_00196.png: inliers = 20
# lizard_00003.png ↔ pond_00199.png: inliers = 19
# lizard_00003.png ↔ pond_00210.png: inliers = 21
# lizard_00003.png ↔ pond_00231.png: inliers = 18
# lizard_00003.png ↔ pond_00274.png: inliers = 19
# lizard_00003.png ↔ pond_00293.png: inliers = 18
# lizard_00003.png ↔ pond_00300.png: inliers = 21
# lizard_00003.png ↔ pond_00306.png: inliers = 20
# lizard_00003.png ↔ pond_00312.png: inliers = 19
# lizard_00003.png ↔ pond_00324.png: inliers = 18
# lizard_00003.png ↔ pond_00333.png: inliers = 19
# lizard_00003.png ↔ pond_00352.png: inliers = 17
# lizard_00003.png ↔ pond_00359.png: inliers = 17
# lizard_00003.png ↔ pond_00421.png: inliers = 18
# lizard_00003.png ↔ pond_00429.png: inliers = 17
# lizard_00003.png ↔ pond_00440.png: inliers = 17
# lizard_00003.png ↔ pond_00450.png: inliers = 17
# lizard_00003.png ↔ pond_00456.png: inliers = 18
# lizard_00003.png ↔ pond_00472.png: inliers = 19
# lizard_00003.png ↔ pond_00474.png: inliers = 17
# lizard_00003.png ↔ pond_00476.png: inliers = 14
# lizard_00003.png ↔ pond_00491.png: inliers = 16
# lizard_00003.png ↔ pond_00493.png: inliers = 19
# lizard_00003.png ↔ pond_00499.png: inliers = 18
# lizard_00003.png ↔ pond_00508.png: inliers = 20
# lizard_00003.png ↔ pond_00509.png: inliers = 18
# lizard_00003.png ↔ pond_00548.png: inliers = 17
# lizard_00003.png ↔ pond_00558.png: inliers = 17
# lizard_00003.png ↔ pond_00567.png: inliers = 18
# lizard_00003.png ↔ pond_00573.png: inliers = 19
# lizard_00003.png ↔ pond_00574.png: inliers = 19
# lizard_00003.png ↔ pond_00596.png: inliers = 20
# lizard_00003.png ↔ pond_00605.png: inliers = 20
# lizard_00003.png ↔ pond_00617.png: inliers = 19
# lizard_00003.png ↔ pond_00634.png: inliers = 19
# lizard_00003.png ↔ pond_00637.png: inliers = 19
# lizard_00003.png ↔ pond_00644.png: inliers = 19
# lizard_00003.png ↔ pond_00658.png: inliers = 19
# lizard_00003.png ↔ pond_00696.png: inliers = 17
# lizard_00003.png ↔ pond_00724.png: inliers = 19
# lizard_00003.png ↔ pond_00726.png: inliers = 15
# lizard_00003.png ↔ pond_00750.png: inliers = 17
# lizard_00003.png ↔ pond_00779.png: inliers = 16
# lizard_00003.png ↔ pond_00793.png: inliers = 14
# lizard_00003.png ↔ pond_00796.png: inliers = 16
# lizard_00003.png ↔ pond_00832.png: inliers = 14
# lizard_00003.png ↔ pond_00834.png: inliers = 19
# lizard_00003.png ↔ pond_00864.png: inliers = 17
# lizard_00003.png ↔ pond_00878.png: inliers = 22
# lizard_00003.png ↔ pond_00893.png: inliers = 20
# lizard_00003.png ↔ pond_00896.png: inliers = 17
# lizard_00003.png ↔ pond_00914.png: inliers = 19
# lizard_00003.png ↔ pond_00915.png: inliers = 18
# lizard_00003.png ↔ pond_00920.png: inliers = 15
# lizard_00003.png ↔ pond_00941.png: inliers = 20
# lizard_00003.png ↔ pond_00955.png: inliers = 18
# lizard_00003.png ↔ pond_00958.png: inliers = 19
# lizard_00003.png ↔ pond_00969.png: inliers = 17
# lizard_00003.png ↔ pond_00974.png: inliers = 16
# lizard_00003.png ↔ pond_00997.png: inliers = 10
# lizard_00003.png ↔ pond_01020.png: inliers = 11
# lizard_00003.png ↔ pond_01024.png: inliers = 13
# lizard_00003.png ↔ pond_01035.png: inliers = 13
# lizard_00003.png ↔ pond_01061.png: inliers = 12
# lizard_00003.png ↔ pond_01068.png: inliers = 14
# lizard_00003.png ↔ pond_01088.png: inliers = 12
# lizard_00003.png ↔ pond_01120.png: inliers = 13
# lizard_00003.png ↔ pond_01131.png: inliers = 16
# lizard_00003.png ↔ pond_01133.png: inliers = 11
# lizard_00003.png ↔ pond_01136.png: inliers = 14
# lizard_00003.png ↔ pond_01138.png: inliers = 11
# Reference image: lizard_00003.png
# Keypoints: 6895
